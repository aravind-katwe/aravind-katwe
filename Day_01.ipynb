# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind-katwe/aravind-katwe/blob/master/Day_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World

# %%
# int float str

# %%
# int - integer

# %%
100/10
# Out:
# 10.0

# %%
a,b=20,30
c=a*b
c
# Out:
# 600
